# %%
import matplotlib.pyplot as plt
import numpy as np
from array_io import *

# %%
fname = "grid.txt"
i,x,n_H, I_p, I_m, J, S, Q_HII, Delta_tau = read_nine_arrays(fname)

# %%
plt.plot(x,n_H)
plt.yscale('log')
plt.xlabel(r'$x$ [$\mathrm{kpc}$]')
plt.ylabel(r'$n_H$ [$\mathrm{cm}^{-3}$]')
# Out:
# Text(0,0.5,'$n_H$ [$\\mathrm{cm}^{-3}$]')

# %%
plt.plot(x,Q_HII)
plt.yscale('log')
plt.xlabel(r'$x$ [$\mathrm{kpc}$]')
plt.ylabel(r'$Q_{HII}$')
plt.ylim([1.0e-5,1.5])
# Out:
# (1e-05, 1.5)
