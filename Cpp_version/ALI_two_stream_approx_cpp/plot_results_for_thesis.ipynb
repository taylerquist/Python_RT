# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.font_manager
from matplotlib import cm
from matplotlib import rc
#rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
#rc('text', usetex=True)
from array_io import *

# %%
#fesc = 0.1, Im = 24, 25, 26

fname_I24 = 'grid.Im_24.txt'
i24, x24, rho24, Ip24, Im24, J24, S24, QHII24, dtau24 = read_nine_arrays(fname_I24)
fname_I25 = 'grid.Im_25.txt'
i25, x25, rho25, Ip25, Im25, J25, S25, QHII25, dtau25 = read_nine_arrays(fname_I25)
fname_I26 = 'grid.Im_26.txt'
i26, x26, rho26, Ip26, Im26, J26, S26, QHII26, dtau26 = read_nine_arrays(fname_I26)

# %%
fname_I25 = 'grid.Im_25.fesc_01.txt'
i25f01, x25f01, rho25f01, Ip25f01, Im25f01, J25f01, S25f01, QHII25f01, dtau25f01 = read_nine_arrays(fname_I25)
fname_I25 = 'grid.Im_25.fesc_1.txt'
i25f1, x25f1, rho25f1, Ip25f1, Im25f1, J25f1, S25f1, QHII25f1, dtau25f1 = read_nine_arrays(fname_I25)

# %%
fname_I2 = 'grid.Im_2e25.txt'
i2, x2, rho2, Ip2, Im2, J2, S2, QHII2, dtau2 = read_nine_arrays(fname_I2)
fname_I2525 = 'grid.Im_25e25.txt'
i2525, x2525, rho2525, Ip2525, Im2525, J2525, S2525, QHII2525, dtau2525 = read_nine_arrays(fname_I2525)
fname_I27525 = 'grid.Im_275e25.txt'
i27525, x27525, rho27525, Ip27525, Im27525, J27525, S27525, QHII27525, dtau27525 = read_nine_arrays(fname_I27525)
fname_I2925 = 'grid.Im_29e25.txt'
i2925, x2925, rho2925, Ip2925, Im2925, J2925, S2925, QHII2925, dtau2925 = read_nine_arrays(fname_I2925)
fname_I292525 = 'grid.Im_2925e25.txt'
i292525, x292525, rho292525, Ip292525, Im292525, J292525, S292525, QHII292525, dtau292525 = read_nine_arrays(fname_I292525)
fname_I29525 = 'grid.Im_295e25.txt'
i29525, x29525, rho29525, Ip29525, Im29525, J29525, S29525, QHII29525, dtau29525 = read_nine_arrays(fname_I29525)
fname_I3 = 'grid.Im_3e25.txt'
i3, x3, rho3, Ip3, Im3, J3, S3, QHII3, dtau3 = read_nine_arrays(fname_I3)
fname_I4 = 'grid.Im_4e25.txt'
i4, x4, rho4, Ip4, Im4, J4, S4, QHII4, dtau4 = read_nine_arrays(fname_I4)
fname_I5 = 'grid.Im_5e25.txt'
i5, x5, rho5, Ip5, Im5, J5, S5, QHII5, dtau5 = read_nine_arrays(fname_I5)
fname_I6 = 'grid.Im_6e25.txt'
i6, x6, rho6, Ip6, Im6, J6, S6, QHII6, dtau6 = read_nine_arrays(fname_I6)
fname_I7 = 'grid.Im_7e25.txt'
i7, x7, rho7, Ip7, Im7, J7, S7, QHII7, dtau7 = read_nine_arrays(fname_I7)
fname_I8 = 'grid.Im_8e25.txt'
i8, x8, rho8, Ip8, Im8, J8, S8, QHII8, dtau8 = read_nine_arrays(fname_I8)
fname_I9 = 'grid.Im_9e25.txt'
i9, x9, rho9, Ip9, Im9, J9, S9, QHII9, dtau9 = read_nine_arrays(fname_I9)

# %%
fig = plt.figure(figsize=(6,6))

fs = 14
plt.xlabel('Radius [kpc]',fontsize=fs)
plt.ylabel('Density [cm$^{-3}$]',fontsize=fs)
plt.plot(x24,rho24)
plt.yscale('log')
#plt.xscale('log')
plt.xlim([90,190])
plt.ylim([1.0e-6,1.0e-3])
plt.gca().tick_params(axis='both',which='both',direction='in')
plt.savefig('density_profile.pdf',bbox_inches='tight',dpi=600)

# %%
fig = plt.figure(figsize=(6,6))



#plt.plot(x25,QHII25)
#plt.plot(x2525,QHII2525)
plt.plot(x27525,QHII27525,label='$I_{-}=2.75$',color=cm.jet(10))
plt.plot(x2925,QHII2925,label='$I_{-}=2.9$',color=cm.jet(20))
plt.plot(x292525,QHII292525,label='$I_{-}=2.925$',color=cm.jet(40))
plt.plot(x29525,QHII29525,label='$I_{-}=2.95$',color=cm.jet(60))

#plt.plot(x2,QHII2)
plt.plot(x3,QHII3,label='$I_{-}=3$',color=cm.jet(80))
plt.plot(x24,QHII24,label='$I_{-}=10$',color=cm.jet(100))

#plt.plot(x4,QHII4)
#plt.plot(x5,QHII5)
#plt.plot(x6,QHII6)
#plt.plot(x7,QHII7)
#plt.plot(x8,QHII8)
#plt.plot(x9,QHII9)

#plt.plot(x26,QHII26)
#plt.plot(x25f01,QHII25f01)
#plt.plot(x25f1,QHII25f1)


#plt.xscale('log')
#plt.yscale('log')
#plt.ylim([1.0e-3,1.1])
plt.xlim([90,190])
fs = 14
plt.xlabel('Radius [kpc]',fontsize=fs)
plt.ylabel('Hydrogen Ionization Fraction',fontsize=fs)
plt.gca().tick_params(axis='both',which='both',direction='in')
plt.legend(loc=4,frameon=False)
plt.savefig('ionization_fraction.pdf',bbox_inches='tight',dpi=600)

# %%
fig = plt.figure(figsize=(6,6))

#plt.plot(x25,J25)
#plt.plot(x2525,J2525)
plt.plot(x27525,J27525,label='$I_{-}=2.75$',color=cm.jet(10))
plt.plot(x2925,J2925,label='$I_{-}=2.9$',color=cm.jet(20))
plt.plot(x292525,J292525,label='$I_{-}=2.925$',color=cm.jet(40))
plt.plot(x29525,J29525,label='$I_{-}=2.95$',color=cm.jet(60))
#plt.plot(x2,J2)
plt.plot(x3,J3,label='$I_{-}=3$',color=cm.jet(80))
#plt.plot(x4,J4)
plt.plot(x24,J24,label='$I_{-}=10$',color=cm.jet(100))

#plt.plot(x5,J5)
#plt.plot(x6,J6)
#plt.plot(x7,J7)
#plt.plot(x8,J8)
#plt.plot(x9,J9)

#plt.plot(x26,J26)

#plt.xscale('log')
plt.yscale('log')
plt.xlim([90,190])
plt.ylim([1.0e-27,1.0e-20])
plt.xlabel('Radius [kpc]',fontsize=fs)
plt.ylabel('Mean Intensity [erg/s/cm$^{2}$/Hz/str]',fontsize=fs)
plt.gca().tick_params(axis='both',which='both',direction='in')
plt.legend(loc=1,frameon=False)
plt.savefig('mean_intensity.pdf',bbox_inches='tight',dpi=600)
